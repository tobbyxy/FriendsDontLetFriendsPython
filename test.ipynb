# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
# Set seed
np.random.seed(666)

# Generate data
data_set = pd.DataFrame(np.random.normal(1, 1, (5, 3)), columns=['V1', 'V2', 'V3'])

# Melt the DataFrame to long format
data_set = data_set.melt(var_name='sample', value_name='Response')

# Replace 'V' with 'group' in the 'sample' column
data_set['Group'] = data_set['sample'].str.replace('V', 'group')

# Display the first few rows
print(data_set.head())
# Out:
#   sample  Response   Group
# 0     V1  1.824188  group1
# 1     V1  1.909048  group1
# 2     V1  1.019028  group1
# 3     V1  0.213557  group1
# 4     V1  1.978222  group1

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Set seed
np.random.seed(666)


# Fit the model
model_1 = smf.ols('Response ~ Group', data=data_set).fit()

# Perform ANOVA
print(anova_lm(model_1))

# Calculate the estimated marginal means
emmeans = model_1.fittedvalues
print(emmeans)
# Out:
#             df    sum_sq   mean_sq         F    PR(>F)
# Group      2.0  0.966676  0.483338  0.813841  0.466182
# Residual  12.0  7.126767  0.593897       NaN       NaN
# 0     1.388809
# 1     1.388809
# 2     1.388809
# 3     1.388809
# 4     1.388809
# 5     0.767287
# 6     0.767287
# 7     0.767287
# 8     0.767287
# 9     0.767287
# 10    1.094960
# 11    1.094960
# 12    1.094960
# 13    1.094960
# 14    1.094960
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a violin plot
violin_eg = sns.violinplot(x='Group', y='Response', data=data_set, palette='Accent', inner='point')

# Add a title
violin_eg.set_title('Points are median.', fontsize=12, color='black', weight='bold')

# Customize the axes and labels
violin_eg.set_xlabel('Group', fontsize=12, color='black', weight='bold')
violin_eg.set_ylabel('Response', fontsize=12, color='black', weight='bold')

# Add a caption
violin_eg.text(x=0.5, y=-0.1, s="The distributions are different!\nI wonder what's going on.", ha='center', va='center', transform=violin_eg.transAxes, fontsize=12)

# Remove the legend
violin_eg.legend_.remove()

# Display the plot
plt.show()
# Out:
# C:\Users\tobia\AppData\Local\Temp\ipykernel_44076\2741757906.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   violin_eg = sns.violinplot(x='Group', y='Response', data=data_set, palette='Accent', inner='point')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 18
#      15 violin_eg.text(x=0.5, y=-0.1, s="The distributions are different!\nI wonder what's going on.", ha='center', va='center', transform=violin_eg.transAxes, fontsize=12)
#      17 # Remove the legend
# ---> 18 violin_eg.legend_.remove()
#      20 # Display the plot
#      21 plt.show()
#
# AttributeError: 'NoneType' object has no attribute 'remove'

# %%
# Create a box plot
box_eg = sns.boxplot(x='Group', y='Response', data=data_set, palette='Accent')

# Add a title
box_eg.set_title('Boxes span IQR.', fontsize=12, color='black', weight='bold')

# Customize the axes and labels
box_eg.set_xlabel('Group', fontsize=12, color='black', weight='bold')
box_eg.set_ylabel('Response', fontsize=12, color='black', weight='bold')

# Add a caption
box_eg.text(x=0.5, y=-0.1, s="The quartiles are different!\nI wonder what's going on.", ha='center', va='center', transform=box_eg.transAxes, fontsize=12)

# Remove the legend
box_eg.legend_.remove()

# Display the plot
plt.show()
# Out:
# C:\Users\tobia\AppData\Local\Temp\ipykernel_44076\306097855.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   box_eg = sns.boxplot(x='Group', y='Response', data=data_set, palette='Accent')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 15
#      12 box_eg.text(x=0.5, y=-0.1, s="The quartiles are different!\nI wonder what's going on.", ha='center', va='center', transform=box_eg.transAxes, fontsize=12)
#      14 # Remove the legend
# ---> 15 box_eg.legend_.remove()
#      17 # Display the plot
#      18 plt.show()
#
# AttributeError: 'NoneType' object has no attribute 'remove'

# %%
# Create a jitter plot
jitter_eg = sns.stripplot(x='Group', y='Response', data=data_set, palette='Accent', jitter=0.2, size=5, edgecolor='gray')

# Add a title
jitter_eg.set_title('n = 5', fontsize=12, color='black', weight='bold')

# Customize the axes and labels
jitter_eg.set_xlabel('Group', fontsize=12, color='black', weight='bold')
jitter_eg.set_ylabel('Response', fontsize=12, color='black', weight='bold')

# Add a caption
jitter_eg.text(x=0.5, y=-0.2, s="Never mind...\nToo little data to say anything.", ha='center', va='center', transform=jitter_eg.transAxes, fontsize=12)

# Display the plot
plt.show()
# Out:
# C:\Users\tobia\AppData\Local\Temp\ipykernel_44076\1782677563.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   jitter_eg = sns.stripplot(x='Group', y='Response', data=data_set, palette='Accent', jitter=0.2, size=5, edgecolor='gray')
# C:\Users\tobia\AppData\Local\Temp\ipykernel_44076\1782677563.py:2: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   jitter_eg = sns.stripplot(x='Group', y='Response', data=data_set, palette='Accent', jitter=0.2, size=5, edgecolor='gray')

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Violin plot
sns.violinplot(x='Group', y='Response', data=data_set, palette='Accent', ax=axs[0])
axs[0].set_title('Violin Plot')
axs[0].text(0.5, -0.2, "The distributions are different!\nI wonder what's going on.", ha='center', va='center', transform=axs[0].transAxes)

# Box plot
sns.boxplot(x='Group', y='Response', data=data_set, palette='Accent', ax=axs[1])
axs[1].set_title('Box Plot')
axs[1].text(0.5, -0.2, "The quartiles are different!\nI wonder what's going on.", ha='center', va='center', transform=axs[1].transAxes)

# Jitter plot
sns.stripplot(x='Group', y='Response', data=data_set, palette='Accent', jitter=0.2, size=5, edgecolor='gray', ax=axs[2])
axs[2].set_title('Jitter Plot')
axs[2].text(0.5, -0.2, "Never mind...\nToo little data to say anything.", ha='center', va='center', transform=axs[2].transAxes)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\tobia\AppData\Local\Temp\ipykernel_44076\849640915.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Group', y='Response', data=data_set, palette='Accent', ax=axs[0])
# C:\Users\tobia\AppData\Local\Temp\ipykernel_44076\849640915.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Response', data=data_set, palette='Accent', ax=axs[1])
# C:\Users\tobia\AppData\Local\Temp\ipykernel_44076\849640915.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Group', y='Response', data=data_set, palette='Accent', jitter=0.2, size=5, edgecolor='gray', ax=axs[2])
# C:\Users\tobia\AppData\Local\Temp\ipykernel_44076\849640915.py:16: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(x='Group', y='Response', data=data_set, palette='Accent', jitter=0.2, size=5, edgecolor='gray', ax=axs[2])
